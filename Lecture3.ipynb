# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('DATA/dog1.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
# here it has a problem like if i pass the wrong file path, instead of showing the error or warning it successfully gets passed
img1 = cv2.imread('DATA/CAT.jpg')

# %%
type(img1)
# Out:
# NoneType

# %%
img.shape
# Out:
# (750, 900, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB -->RED, GREEN, BLUE
#OPENCV ---> BLUE, GREEN RED

fix_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('DATA/dog1.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
fix_img.shape
# Out:
# (750, 900, 3)

# %%
new_img=cv2.resize(fix_img,(1000,400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.8
h_ratio = 0.2

# %%
new_img = cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (375, 450, 3)

# %%
375*5
# Out:
# 1875

# %%
new_img = cv2.flip(fix_img, -1)
plt.imshow(new_img)

# %%
# where i wrote -1 we can write 1, 0 and accordingly it will change

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg', fix_img)
# Out:
# True

# %% [markdown]
# # How much blank canvas space I can use in Jupyter notebook

# %%
fig = plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
ax.imshow(fix_img)
